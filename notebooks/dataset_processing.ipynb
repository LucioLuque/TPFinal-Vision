# %%
import sys 
import os
sys.path.append(os.path.abspath(os.path.join("..", "src")))
from prepare_dataset import prepare_sr_dataset
# %load_ext autoreload
# %autoreload 2

# %%
data = "General100"
folder_dir = "../Datasets/Train"
image_dir = f"{folder_dir}/{data}/"

f = 4
out_dir = f"{folder_dir}/{data}_x{f}/"
prepare_sr_dataset(image_dir, out_dir, patch_size=33, scale=f, num_patches_per_image=550)
# Out:
# ...
# Processing val: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# Total training patches: 44000
# Total validation patches: 11000
